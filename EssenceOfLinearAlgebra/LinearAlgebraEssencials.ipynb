# %% [markdown]
# # Essence of linear algebra - Playlist:
# https://www.youtube.com/watch?v=fNk_zzaMoSs&list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab&index=2&t=55s

# %% [markdown]
# ### Video No 01:
#
# El vector es la unidad fundamental del algebra lineal: Tenemos tres perspectivas:
#
# * Fisicas: Representan magnitudes, viven en dos o tres dimensiones (flechitas).
#
# * CS Students: List of numbers, el nombre importa.
#
# * Math: Super formal, out of the scoop.
#
#
# En cuanto a notacion, un vector se representa como un arreglo de vectores de la siguiente forma:
#
# <img src="Imagenes/img01_LA.png">
#
#
# * Con los vectores, pueden sumarse entre si (cuando tienen la misma cantidad de elementos.
#
# * Multiplicaicion por escalares, "Scaling"
#
# ## Video No 02:
#
# Cada coordenada es un escalar. Otra representacion para los vectores: Vectores unitarios:
#
# <img src="Imagenes/img02_LA.png">
#
#
# Utilizando **n** cantidad de escalares, podemos obtneer un sin fin de posibles vectores, a partir de vectores unitarios.
#
# Combinacion lineal de vectores:
#
# <img src="Imagenes/img03_LA.png">
#
# **Dependencia lineal entre vectores**
#
# Es como ver la redundancia entre vectores, por ejemplo, si tenemos la operacion lineal entre dos vectores paralalos, entonces esos dos vectores tienen dependencia lineal entre si, porque podriamos eliminar uno de esos dos vectroes y tomar el "span" unicamente como la combinacion lineal de uno solo.
#
# Lo mimso aplica para espacioes en 3d pero cuando tenemos tres vectores coplanares.
#
#
# <img src="Imagenes/img04_LA.png">
#
# <img src="Imagenes/img05_LA.png">

# %% [markdown]
# ## Video No. 03:
#
# **Matrices como transformaciones lineales**
#
#
# Transformacion, no es mas que pasar un vector por una fucion y modificar su valor. Es decir, las transformacione lineales modifican un vector en otro vector, y todo eso se lleva a cabo utiizando transformaciones lineales.
#
# V => Transformacion () => W
#
# Entonces, quiere decir que el vector V se transformó en el vector W utilizando transformaciones lineales.
#
# Transformaciones lineales (dos propiedades):
#
# * Todas la slineas siguen siendo lineas
# * El origen sigue siendo el mismo.
#
# Como describimos de manera numerica las transformaciones lineales:
#
# A travez de vectores:
#
# <img src="Imagenes/img06_LA.png">
#
# Basicamente al multiplicar todo el espacio, por un vector, lo modificamos, dando lugar a otro sistema de coordenadas. El sistema de coordenadas resultantes contiene al original y viceversa (**esto es una propiedad de las tranformaciones lineales????!!!**)
#
# Las marices pueden ser entendidas como conjuntos de vectores y la multiplicacion matricial puede ser interpretada como un conjunto de productos puntos.
#
# <img src="Imagenes/img07_LA.png">
#
#
# ## Video No. 04:
#
# Una transformacion lineal, combierte un espacio en otro. Toda transformacion lineal puede decirse que es la combinacion de varias transformaciones lineales mas pequeñas (basicas):
#
#
# <img src="Imagenes/img08_LA.png">
#
# Jerarquia de las transformaciones:
#
# <img src="Imagenes/img09_LA.png">
#
#
#
# El orden en que se aplican las transformaciones si importa, es decir:
#
# <img src="Imagenes/img10_LA.png">
#
# ## Video 05:
#
# Lo mismo del video anterior se puede extrapolar al plano en R3

# %% [markdown]
# ## Video 06:
#
# Que tanto se escalan las áreas en una transformacion lineal? Asumiendo un grid de cuadrados, lo que le pase a un cuadrado le pasará al resto de cuadrados en el grid:
#
# <img src="Imagenes/img11_LA.png">
#
# Aun si una forma cualuqiera no necesariamente no es un cuadrado, puede ser descompuesta por una serie de cuadrados.
#
# <img src="Imagenes/img12_LA.png">
#
# **Un determinante es un el factor por el cual el area se incrementa**
#
#
# **NOTA IMPORTANTE: SI EL DETERMINANTE DE DE UNA MATRIZ ES CERO, COMPRIME TODO EL ESPACIO EN UNA SOLA LINEA O INCLUSO EN UN UNICO PUNTO**
#
#
# Y que pasa si el determinante es negativo? **ESO QUIERE DECIR QUE EL PLANO TOTAL SE INVIERTE
#
# <img src="Imagenes/img13_LA.png">
#
# Si multiplicamos los determinantes de dos matrices, el determinante de la matriz resultante será el mismo que el producto de los dos determnantes individuales??? Good question!!!!
#
# ## Video 07:
#
# Las matrices pueden utilizarse para representar sistemas de ecuaciones lineales.
#
# <img src="Imagenes/img14_LA.png">
#
# La matriz A es una transformacion lineal. Ahora bien, hay un concepto interesante en cuanto a las transformaciones de la matriz A.
#
# <img src="Imagenes/img15_LA.png">
#
# La matriz A por la inversa de la misma matriz, nos devuelve una matriz que no hace practicamente nada. Y esta matriz es la **Matriz Identidad**
#
# Pero...... que pasa si el determonante **ES CERO!!!!**, cuando el determinante es cero, significa que se degradó una demnsion (es decir, no tiene area o no tiene volumen y es imposible, revertirlo, es decir, no se puede encontrar la matriz inversa.
#
# No podemos convertir un punto o liena en un plano unico. Y un plano en un volumen unico.
#
#
# **Pero que pasa cuando el determinante es cero, eso significa entonces que no se tiene una solucion unica? o que tan siquiera tiene solucion....???
#
# Pues: Esto passa cuando el determinante es cero (es decir, no existe una matriz inversa) pero aun asi, puede tener solucion el sistema lineal
#
# <img src="Imagenes/img16_LA.png">
#
# Entonces que pasa cuando las transformaciones generan:
#
# * 1 punto: Rank 0
# * 1 linea: Rank 1 (una dimension)
# * 1 plano: Rank 2 (dos dimensiones)
#
# **Rank: Is the number of dimensions in the output of certain transformation**
#
# Column space:
#
# <img src="Imagenes/img17_LA.png">
#
# <img src="Imagenes/img18_LA.png">
#
# <img src="Imagenes/img19_LA.png">
#
# **Rank: The number of dimensions in the column space**
#
# Cuando el culumn space es el maximo posible (iguala a la matriz en si) entonces es **Full rank**
#
# **Null Space** linea compuesta por vectores que pasan por el origen
#
# =========================================================================

# %% [markdown]
# ## Video 08:
#
# Unicmanete hemos hablado de transformaciones de 2d Vectors por matrices de 2d vectors. No es la unica posibilidad:
#
# <img src="Imagenes/img20_LA.png">
#
# <img src="Imagenes/img21_LA.png">

# %% [markdown]
# ## Video 09:
#
# Geométricmente, son reflecciones de vectores sobre otros vectores, cuando el producto punto es cero, significa **que los vectores son perpendiculares** El producto punto aplica para vectores unicamente del mismo grado. El orden en el que se orientan los vectores no importan.
#
# <img src="Imagenes/img22_LA.png">
#
# Si dos vectores son de igual magnitud, la refleccion del vector **A** sobre el vector **B** será la misma que la de **B** sobre el vector **A**:
#
# Transformaciones lineales:
#
# <img src="Imagenes/img23_LA.png">
#
# Podemos pensar en el producto punto como una transformacion lineal, que convierte nuestro vector a de grado "n" hacia un escalar:
#
# <img src="Imagenes/img24_LA.png">

# %% [markdown]
# # Video 10
#
# **Cross product:** Lo primero que debemos saber es que el orden de los factores importa. Geometricamente, es el area de un parelogramo (en un 2d vector y solo para el valor numerico). Como el producto cruz es un vector, la direccion sera perpendicular al paralelogramo.
#
# <img src="Imagenes/img25_LA.png">
#
# Como calcular el producto punto:
#
# <img src="Imagenes/img26_LA.png">

# %% [markdown]
# # Video 11:
#
# Una forma de calccular el producto cruz, es justo como observamos een la ultima imagen del video anterior. La cuestion es, por que tomamos los vectores unitarios en la primera columna de la matriz a la que le extraemos el determinante?
#
#
# Lo interesante son las propiedades geometricas del vector resultante:
#
#
# <img src="Imagenes/img27_LA.png">
#
# <img src="Imagenes/img28_LA.png">
#
# <img src="Imagenes/img29_LA.png">

# %% [markdown]
# # Video 12
#
# Regla de cramer: Para la solucion de ecuaciones lineales:
#
# <img src="Imagenes/img30_LA.png">

# %% [markdown]
# # Video 13
#
# Un vector no es mas que un conjunto de escalares que "escalan"  los vectores unitarios.
#
# Bajo este precepto, los vectores i, j y k son los vectores basicos (basics vectors).
#
# Pero no son los unicos.

# %% [markdown]
# # Video 14: Eigenvalues and Eigenvectors
#
# Que significan realmente. Sin embargo, se necesita entender determinantes, cambios de bases, sistemas de base  y transformaciones.
#
#
# <img src="Imagenes/img31_LA.png">
#
# <img src="Imagenes/img32_LA.png">
#
# <img src="Imagenes/img33_LA.png">
#
# **No todas las transformaciones lineales tienen eigenvectores, ergo eigenvalues** Las rotaciones sobre el origen por ejemplo no tienen esta propiedad.
#
# Un eigenvalues **puede estar asociado a varios eigenvectores**
#
# Pendiente Eigenbasis.
